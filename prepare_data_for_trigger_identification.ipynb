# %% [markdown]
# <a href="https://colab.research.google.com/github/comp-aspects-of-appl-linguistics/relation-extraction-utils/blob/master/prepare_data_for_trigger_identification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### PRERATIONS:

# STEP 1: ensure 'relation_extraction_utils' is installed - as stanfordnlp is 
#         a dependency of 'relation_extraction_utils' it will be installed if 
#         necessary.
#         Additionally, stanfordnlp_resources are downloaded if nt alread present
# !pip install git+https://github.com/comp-aspects-of-appl-linguistics/relation_extraction_utils.git

import os
import stanfordnlp

if not os.path.exists('/root/stanfordnlp_resources'):
  stanfordnlp.download('en', force=True)

  
# STEP 2: we'll need to access Google Drive to fetch the 'train.json' file -
#         at the end of the next snippet will be promted to click a link from
#         which the user will be able to generate an Oath token to be copied 
#         at the prompt
  
# !pip install PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)


# NOTE: The id of the file assigned to 'train.json' may change
drive_id_for_train_json_file='1nPpp1zs3_0rkPkCvuz-dSK4YygxO6lw1'

# get the file into our current environment's file system
downloaded = drive.CreateFile({'id':drive_id_for_train_json_file}) 
downloaded.GetContentFile('train.json')

# %%
#### This is where the work happens:

# OUTCOME: output.csv file is generated in the current directory.
#          it has the following columns populated columns:
#               1) counter
#               2) sentence
#               3) ent1 (the text representation)
#               4) ent2 (the text representation)
#               5) dependency parse
#               6) index lookup
#          and the following empty ones: 
#               7) trigger (single word)
#               8) trigger_idx
#               9) ent1_start
#              10) ent1_end
#              11) ent2_start
#              12) ent2_end
#              13) comments


from prepare_for_trigger_identification.cvs_file import generate_csv_file

input_path = './train.json'
relation_name = 'per:employee_of'
output_path = './output.csv'

generate_csv_file(input_path, relation_name, output_path)

# %%
# Use this cell to expose the output.cvs file. The output can be copied and pasted
# into a local file for further processing

# !cat output.csv
# Out:
# counter,sentence,ent1,ent2,dependency_parse,index_lookup,trigger,trigger_idx,ent1_start,ent1_end,ent2_start,ent2_end,comments
# 1,"Olivia Palermo was looking very Blair Waldorfish at last week's You Know You Want It: Style-Inspiration-Confidence book launch, so it's only fitting she ran into real-life Gossip Girl s Leighton Meester and Nicole Fiscella on her way there!",Gossip Girl,Olivia Palermo,"[('1', 'Olivia', 'nsubj', '4', 'looking'), ('2', 'Palermo', 'flat', '1', 'Olivia'), ('3', 'was', 'aux', '4', 'looking'), ('4', 'looking', 'root', '0', 'ROOT'), ('5', 'very', 'advmod', '6', 'Blair'), ('6', 'Blair', 'obj', '4', 'looking'), ('7', 'Waldorfish', 'flat', '6', 'Blair'), ('8', 'at', 'case', '10', 'week'), ('9', 'last', 'amod', '10', 'week'), ('10', 'week', 'obl', '4', 'looking'), ('11', ""'s"", 'case', '10', 'week'), ('12', 'You', 'nsubj', '13', 'Know'), ('13', 'Know', 'parataxis', '4', 'looking'), ('14', 'You', 'nsubj', '15', 'Want'), ('15', 'Want', 'ccomp', '13', 'Know'), ('16', 'It', 'obj', '15', 'Want'), ('17', ':', 'punct', '15', 'Want'), ('18', 'Style', 'compound', '24', 'launch'), ('19', '-', 'punct', '18', 'Style'), ('20', 'Inspiration', 'compound', '22', 'Confidence'), ('21', '-', 'punct', '22', 'Confidence'), ('22', 'Confidence', 'compound', '23', 'book'), ('23', 'book', 'compound', '24', 'launch'), ('24', 'launch', 'obj', '15', 'Want'), ('25', ',', 'punct', '30', 'fitting'), ('26', 'so', 'advmod', '30', 'fitting'), ('27', 'it', 'nsubj', '30', 'fitting'), ('28', ""'s"", 'aux', '30', 'fitting'), ('29', 'only', 'advmod', '30', 'fitting'), ('30', 'fitting', 'parataxis', '4', 'looking'), ('31', 'she', 'nsubj', '32', 'ran'), ('32', 'ran', 'ccomp', '30', 'fitting'), ('33', 'into', 'case', '40', 'Leighton'), ('34', 'real', 'amod', '36', 'life'), ('35', '-', 'punct', '36', 'life'), ('36', 'life', 'compound', '38', 'Girl'), ('37', 'Gossip', 'compound', '38', 'Girl'), ('38', 'Girl', 'nmod:poss', '40', 'Leighton'), ('39', 's', 'case', '38', 'Girl'), ('40', 'Leighton', 'obl', '32', 'ran'), ('41', 'Meester', 'flat', '40', 'Leighton'), ('42', 'and', 'cc', '43', 'Nicole'), ('43', 'Nicole', 'conj', '40', 'Leighton'), ('44', 'Fiscella', 'flat', '43', 'Nicole'), ('45', 'on', 'case', '47', 'way'), ('46', 'her', 'nmod:poss', '47', 'way'), ('47', 'way', 'obl', '32', 'ran'), ('48', 'there', 'advmod', '47', 'way'), ('49', '!', 'punct', '4', 'looking')]","'Olivia': 1
# 'Palermo': 2
# 'was': 3
# 'looking': 4
# 'very': 5
# 'Blair': 6
# 'Waldorfish': 7
# 'at': 8
# 'last': 9
# 'week': 10
# ''s': 11
# 'You': 12
# 'Know': 13
# 'You': 14
# 'Want': 15
# 'It': 16
# ':': 17
# 'Style': 18
# '-': 19
# 'Inspiration': 20
# '-': 21
# 'Confidence': 22
# 'book': 23
# 'launch': 24
# ',': 25
# 'so': 26
# 'it': 27
# ''s': 28
# 'only': 29
# 'fitting': 30
# 'she': 31
# 'ran': 32
# 'into': 33
# 'real': 34
# '-': 35
# 'life': 36
# 'Gossip': 37
# 'Girl': 38
# 's': 39
# 'Leighton': 40
# 'Meester': 41
# 'and': 42
# 'Nicole': 43
# 'Fiscella': 44
# 'on': 45
# 'her': 46
# 'way': 47
# 'there': 48
# '!': 49"
# 2,"Donald Wildmon, the founder and head of the American Family Association, is asking its members to petition Congress to end all funding for PBS.",American Family Association,Donald Wildmon,"[('1', 'Donald', 'nsubj', '15', 'asking'), ('2', 'Wildmon', 'flat', '1', 'Donald'), ('3', ',', 'punct', '1', 'Donald'), ('4', 'the', 'det', '5', 'founder'), ('5', 'founder', 'appos', '1', 'Donald'), ('6', 'and', 'cc', '7', 'head'), ('7', 'head', 'conj', '5', 'founder'), ('8', 'of', 'case', '12', 'Association'), ('9', 'the', 'det', '12', 'Association'), ('10', 'American', 'compound', '12', 'Association'), ('11', 'Family', 'compound', '12', 'Association'), ('12', 'Association', 'nmod', '7', 'head'), ('13', ',', 'punct', '15', 'asking'), ('14', 'is', 'aux', '15', 'asking'), ('15', 'asking', 'root', '0', 'ROOT'), ('16', 'its', 'nmod:poss', '17', 'members'), ('17', 'members', 'obj', '15', 'asking'), ('18', 'to', 'mark', '19', 'petition'), ('19', 'petition', 'acl', '17', 'members'), ('20', 'Congress', 'obj', '19', 'petition'), ('21', 'to', 'mark', '22', 'end'), ('22', 'end', 'advcl', '19', 'petition'), ('23', 'all', 'det', '24', 'funding'), ('24', 'funding', 'obj', '22', 'end'), ('25', 'for', 'case', '26', 'PBS'), ('26', 'PBS', 'nmod', '24', 'funding'), ('27', '.', 'punct', '15', 'asking')]","'Donald': 1
# 'Wildmon': 2
# ',': 3
# 'the': 4
# 'founder': 5
# 'and': 6
# 'head': 7
# 'of': 8
# 'the': 9
# 'American': 10
# 'Family': 11
# 'Association': 12
# ',': 13
# 'is': 14
# 'asking': 15
# 'its': 16
# 'members': 17
# 'to': 18
# 'petition': 19
# 'Congress': 20
# 'to': 21
# 'end': 22
# 'all': 23
# 'funding': 24
# 'for': 25
# 'PBS': 26
# '.': 27"
# 3,"The Rev. George Young, pastor of Holy Temple Baptist Church in Oklahoma City, has taught dozens of secular marriage skills courses to low-income men and women and was an adviser to the governor's office.",Holy Temple Baptist Church,George Young,"[('1', 'The', 'det', '2', 'Rev.'), ('2', 'Rev.', 'nsubj', '17', 'taught'), ('3', 'George', 'flat', '2', 'Rev.'), ('4', 'Young', 'flat', '2', 'Rev.'), ('5', ',', 'punct', '2', 'Rev.'), ('6', 'pastor', 'appos', '2', 'Rev.'), ('7', 'of', 'case', '11', 'Church'), ('8', 'Holy', 'compound', '11', 'Church'), ('9', 'Temple', 'compound', '11', 'Church'), ('10', 'Baptist', 'compound', '11', 'Church'), ('11', 'Church', 'nmod', '6', 'pastor'), ('12', 'in', 'case', '14', 'City'), ('13', 'Oklahoma', 'compound', '14', 'City'), ('14', 'City', 'nmod', '11', 'Church'), ('15', ',', 'punct', '17', 'taught'), ('16', 'has', 'aux', '17', 'taught'), ('17', 'taught', 'root', '0', 'ROOT'), ('18', 'dozens', 'obj', '17', 'taught'), ('19', 'of', 'case', '23', 'courses'), ('20', 'secular', 'amod', '23', 'courses'), ('21', 'marriage', 'compound', '22', 'skills'), ('22', 'skills', 'compound', '23', 'courses'), ('23', 'courses', 'nmod', '18', 'dozens'), ('24', 'to', 'case', '28', 'men'), ('25', 'low', 'amod', '27', 'income'), ('26', '-', 'punct', '27', 'income'), ('27', 'income', 'compound', '28', 'men'), ('28', 'men', 'obl', '17', 'taught'), ('29', 'and', 'cc', '30', 'women'), ('30', 'women', 'conj', '28', 'men'), ('31', 'and', 'cc', '34', 'adviser'), ('32', 'was', 'cop', '34', 'adviser'), ('33', 'an', 'det', '34', 'adviser'), ('34', 'adviser', 'conj', '17', 'taught'), ('35', 'to', 'case', '39', 'office'), ('36', 'the', 'det', '37', 'governor'), ('37', 'governor', 'nmod:poss', '39', 'office'), ('38', ""'s"", 'case', '37', 'governor'), ('39', 'office', 'nmod', '34', 'adviser'), ('40', '.', 'punct', '17', 'taught')]","'The': 1
# 'Rev.': 2
# 'George': 3
# 'Young': 4
# ',': 5
# 'pastor': 6
# 'of': 7
# 'Holy': 8
# 'Temple': 9
# 'Baptist': 10
# 'Church': 11
# 'in': 12
# 'Oklahoma': 13
# 'City': 14
# ',': 15
# 'has': 16
# 'taught': 17
# 'dozens': 18
# 'of': 19
# 'secular': 20
# 'marriage': 21
# 'skills': 22
# 'courses': 23
# 'to': 24
# 'low': 25
# '-': 26
# 'income': 27
# 'men': 28
# 'and': 29
# 'women': 30
# 'and': 31
# 'was': 32
# 'an': 33
# 'adviser': 34
# 'to': 35
# 'the': 36
# 'governor': 37
# ''s': 38
# 'office': 39
# '.': 40"
# 4,"Julian Bond, chairman of the board of the National Association for the Advancement of Colored People, said Gordon tried to quit just six weeks after taking the job in August 2005, but Bond convinced him to stay.",National Association for the Advancement of Colored People,Julian Bond,"[('1', 'Julian', 'nsubj', '19', 'said'), ('2', 'Bond', 'flat', '1', 'Julian'), ('3', ',', 'punct', '1', 'Julian'), ('4', 'chairman', 'appos', '1', 'Julian'), ('5', 'of', 'case', '7', 'board'), ('6', 'the', 'det', '7', 'board'), ('7', 'board', 'nmod', '4', 'chairman'), ('8', 'of', 'case', '11', 'Association'), ('9', 'the', 'det', '11', 'Association'), ('10', 'National', 'compound', '11', 'Association'), ('11', 'Association', 'nmod', '7', 'board'), ('12', 'for', 'case', '17', 'People'), ('13', 'the', 'det', '17', 'People'), ('14', 'Advancement', 'compound', '17', 'People'), ('15', 'of', 'case', '16', 'Colored'), ('16', 'Colored', 'nmod', '14', 'Advancement'), ('17', 'People', 'nmod', '11', 'Association'), ('18', ',', 'punct', '19', 'said'), ('19', 'said', 'root', '0', 'ROOT'), ('20', 'Gordon', 'nsubj', '21', 'tried'), ('21', 'tried', 'ccomp', '19', 'said'), ('22', 'to', 'mark', '23', 'quit'), ('23', 'quit', 'xcomp', '21', 'tried'), ('24', 'just', 'advmod', '25', 'six'), ('25', 'six', 'nummod', '26', 'weeks'), ('26', 'weeks', 'obl:npmod', '28', 'taking'), ('27', 'after', 'mark', '28', 'taking'), ('28', 'taking', 'advcl', '23', 'quit'), ('29', 'the', 'det', '30', 'job'), ('30', 'job', 'obj', '28', 'taking'), ('31', 'in', 'case', '32', 'August'), ('32', 'August', 'obl', '28', 'taking'), ('33', '2005', 'nummod', '32', 'August'), ('34', ',', 'punct', '37', 'convinced'), ('35', 'but', 'cc', '37', 'convinced'), ('36', 'Bond', 'nsubj', '37', 'convinced'), ('37', 'convinced', 'conj', '19', 'said'), ('38', 'him', 'obj', '37', 'convinced'), ('39', 'to', 'mark', '40', 'stay'), ('40', 'stay', 'xcomp', '37', 'convinced'), ('41', '.', 'punct', '19', 'said')]","'Julian': 1
# 'Bond': 2
# ',': 3
# 'chairman': 4
# 'of': 5
# 'the': 6
# 'board': 7
# 'of': 8
# 'the': 9
# 'National': 10
# 'Association': 11
# 'for': 12
# 'the': 13
# 'Advancement': 14
# 'of': 15
# 'Colored': 16
# 'People': 17
# ',': 18
# 'said': 19
# 'Gordon': 20
# 'tried': 21
# 'to': 22
# 'quit': 23
# 'just': 24
# 'six': 25
# 'weeks': 26
# 'after': 27
# 'taking': 28
# 'the': 29
# 'job': 30
# 'in': 31
# 'August': 32
# '2005': 33
# ',': 34
# 'but': 35
# 'Bond': 36
# 'convinced': 37
# 'him': 38
# 'to': 39
# 'stay': 40
# '.': 41"
# 5,"Cuban army general Raul Castro was elected president of Cuba Sunday to replace his brother Fidel Castro, during a legislative session at Cuba's Palace of Conventions in the capital Havana.",army,his,"[('1', 'Cuban', 'amod', '2', 'army'), ('2', 'army', 'compound', '3', 'general'), ('3', 'general', 'compound', '4', 'Raul'), ('4', 'Raul', 'nsubj:pass', '7', 'elected'), ('5', 'Castro', 'flat', '4', 'Raul'), ('6', 'was', 'aux:pass', '7', 'elected'), ('7', 'elected', 'root', '0', 'ROOT'), ('8', 'president', 'xcomp', '7', 'elected'), ('9', 'of', 'case', '10', 'Cuba'), ('10', 'Cuba', 'nmod', '8', 'president'), ('11', 'Sunday', 'obl:tmod', '7', 'elected'), ('12', 'to', 'mark', '13', 'replace'), ('13', 'replace', 'advcl', '7', 'elected'), ('14', 'his', 'nmod:poss', '15', 'brother'), ('15', 'brother', 'obj', '13', 'replace'), ('16', 'Fidel', 'appos', '15', 'brother'), ('17', 'Castro', 'flat', '16', 'Fidel'), ('18', ',', 'punct', '13', 'replace'), ('19', 'during', 'case', '22', 'session'), ('20', 'a', 'det', '22', 'session'), ('21', 'legislative', 'amod', '22', 'session'), ('22', 'session', 'obl', '13', 'replace'), ('23', 'at', 'case', '26', 'Palace'), ('24', 'Cuba', 'nmod:poss', '26', 'Palace'), ('25', ""'s"", 'case', '24', 'Cuba'), ('26', 'Palace', 'nmod', '22', 'session'), ('27', 'of', 'case', '28', 'Conventions'), ('28', 'Conventions', 'nmod', '26', 'Palace'), ('29', 'in', 'case', '32', 'Havana'), ('30', 'the', 'det', '32', 'Havana'), ('31', 'capital', 'amod', '32', 'Havana'), ('32', 'Havana', 'nmod', '26', 'Palace'), ('33', '.', 'punct', '7', 'elected')]","'Cuban': 1
# 'army': 2
# 'general': 3
# 'Raul': 4
# 'Castro': 5
# 'was': 6
# 'elected': 7
# 'president': 8
# 'of': 9
# 'Cuba': 10
# 'Sunday': 11
# 'to': 12
# 'replace': 13
# 'his': 14
# 'brother': 15
# 'Fidel': 16
# 'Castro': 17
# ',': 18
# 'during': 19
# 'a': 20
# 'legislative': 21
# 'session': 22
# 'at': 23
# 'Cuba': 24
# ''s': 25
# 'Palace': 26
# 'of': 27
# 'Conventions': 28
# 'in': 29
# 'the': 30
# 'capital': 31
# 'Havana': 32
# '.': 33"
# 6,"While Whitney Port, Kelly Cutrone and Roxy Olin of MTV's ""The City"" were styling a shoot at Grand Central Terminal for Style212.com for an upcoming episode, police came over to break up a crowd gathered around the cast.",MTV,Kelly Cutrone,"[('1', 'While', 'mark', '18', 'styling'), ('2', 'Whitney', 'compound', '3', 'Port'), ('3', 'Port', 'compound', '5', 'Kelly'), ('4', ',', 'punct', '18', 'styling'), ('5', 'Kelly', 'nsubj', '18', 'styling'), ('6', 'Cutrone', 'flat', '5', 'Kelly'), ('7', 'and', 'cc', '8', 'Roxy'), ('8', 'Roxy', 'conj', '5', 'Kelly'), ('9', 'Olin', 'flat', '8', 'Roxy'), ('10', 'of', 'case', '15', 'City'), ('11', 'MTV', 'nmod:poss', '15', 'City'), ('12', ""'s"", 'case', '11', 'MTV'), ('13', '""', 'punct', '15', 'City'), ('14', 'The', 'det', '15', 'City'), ('15', 'City', 'nmod', '5', 'Kelly'), ('16', '""', 'punct', '15', 'City'), ('17', 'were', 'aux', '18', 'styling'), ('18', 'styling', 'advcl', '33', 'came'), ('19', 'a', 'det', '20', 'shoot'), ('20', 'shoot', 'obj', '18', 'styling'), ('21', 'at', 'case', '24', 'Terminal'), ('22', 'Grand', 'compound', '24', 'Terminal'), ('23', 'Central', 'compound', '24', 'Terminal'), ('24', 'Terminal', 'nmod', '20', 'shoot'), ('25', 'for', 'case', '26', 'Style212.com'), ('26', 'Style212.com', 'obl', '18', 'styling'), ('27', 'for', 'case', '30', 'episode'), ('28', 'an', 'det', '30', 'episode'), ('29', 'upcoming', 'amod', '30', 'episode'), ('30', 'episode', 'obl', '18', 'styling'), ('31', ',', 'punct', '33', 'came'), ('32', 'police', 'nsubj', '33', 'came'), ('33', 'came', 'root', '0', 'ROOT'), ('34', 'over', 'advmod', '33', 'came'), ('35', 'to', 'mark', '36', 'break'), ('36', 'break', 'advcl', '33', 'came'), ('37', 'up', 'compound:prt', '36', 'break'), ('38', 'a', 'det', '39', 'crowd'), ('39', 'crowd', 'obj', '36', 'break'), ('40', 'gathered', 'acl', '39', 'crowd'), ('41', 'around', 'case', '43', 'cast'), ('42', 'the', 'det', '43', 'cast'), ('43', 'cast', 'obl', '40', 'gathered'), ('44', '.', 'punct', '33', 'came')]","'While': 1
# 'Whitney': 2
# 'Port': 3
# ',': 4
# 'Kelly': 5
# 'Cutrone': 6
# 'and': 7
# 'Roxy': 8
# 'Olin': 9
# 'of': 10
# 'MTV': 11
# ''s': 12
# '""': 13
# 'The': 14
# 'City': 15
# '""': 16
# 'were': 17
# 'styling': 18
# 'a': 19
# 'shoot': 20
# 'at': 21
# 'Grand': 22
# 'Central': 23
# 'Terminal': 24
# 'for': 25
# 'Style212.com': 26
# 'for': 27
# 'an': 28
# 'upcoming': 29
# 'episode': 30
# ',': 31
# 'police': 32
# 'came': 33
# 'over': 34
# 'to': 35
# 'break': 36
# 'up': 37
# 'a': 38
# 'crowd': 39
# 'gathered': 40
# 'around': 41
# 'the': 42
# 'cast': 43
# '.': 44"
# 7,"Carson , 33, has been a member of the Indianapolis City-County Council since August.",Indianapolis City-County Council,Carson,"[('1', 'Carson', 'nsubj', '8', 'member'), ('2', ',', 'punct', '1', 'Carson'), ('3', '33', 'amod', '1', 'Carson'), ('4', ',', 'punct', '8', 'member'), ('5', 'has', 'aux', '8', 'member'), ('6', 'been', 'cop', '8', 'member'), ('7', 'a', 'det', '8', 'member'), ('8', 'member', 'root', '0', 'ROOT'), ('9', 'of', 'case', '15', 'Council'), ('10', 'the', 'det', '15', 'Council'), ('11', 'Indianapolis', 'compound', '15', 'Council'), ('12', 'City', 'compound', '14', 'County'), ('13', '-', 'punct', '14', 'County'), ('14', 'County', 'compound', '15', 'Council'), ('15', 'Council', 'nmod', '8', 'member'), ('16', 'since', 'case', '17', 'August'), ('17', 'August', 'obl', '8', 'member'), ('18', '.', 'punct', '8', 'member')]","'Carson': 1
# ',': 2
# '33': 3
# ',': 4
# 'has': 5
# 'been': 6
# 'a': 7
# 'member': 8
# 'of': 9
# 'the': 10
# 'Indianapolis': 11
# 'City': 12
# '-': 13
# 'County': 14
# 'Council': 15
# 'since': 16
# 'August': 17
# '.': 18"
# 8,"Mia Farrow, a UN goodwill ambassador, has labeled the Beijing Games the ""genocide Olympics"" and has launched her own Olympic - style torch relay through countries with histories of mass atrocities.",UN,Mia Farrow,"[('1', 'Mia', 'nsubj', '10', 'labeled'), ('2', 'Farrow', 'flat', '1', 'Mia'), ('3', ',', 'punct', '1', 'Mia'), ('4', 'a', 'det', '7', 'ambassador'), ('5', 'UN', 'compound', '7', 'ambassador'), ('6', 'goodwill', 'compound', '7', 'ambassador'), ('7', 'ambassador', 'appos', '1', 'Mia'), ('8', ',', 'punct', '10', 'labeled'), ('9', 'has', 'aux', '10', 'labeled'), ('10', 'labeled', 'root', '0', 'ROOT'), ('11', 'the', 'det', '13', 'Games'), ('12', 'Beijing', 'compound', '13', 'Games'), ('13', 'Games', 'obj', '10', 'labeled'), ('14', 'the', 'det', '17', 'Olympics'), ('15', '""', 'punct', '17', 'Olympics'), ('16', 'genocide', 'compound', '17', 'Olympics'), ('17', 'Olympics', 'obj', '10', 'labeled'), ('18', '""', 'punct', '17', 'Olympics'), ('19', 'and', 'cc', '21', 'launched'), ('20', 'has', 'aux', '21', 'launched'), ('21', 'launched', 'conj', '10', 'labeled'), ('22', 'her', 'nmod:poss', '28', 'relay'), ('23', 'own', 'amod', '28', 'relay'), ('24', 'Olympic', 'compound', '26', 'style'), ('25', '-', 'punct', '26', 'style'), ('26', 'style', 'compound', '28', 'relay'), ('27', 'torch', 'compound', '28', 'relay'), ('28', 'relay', 'obj', '21', 'launched'), ('29', 'through', 'case', '30', 'countries'), ('30', 'countries', 'obl', '21', 'launched'), ('31', 'with', 'case', '32', 'histories'), ('32', 'histories', 'nmod', '30', 'countries'), ('33', 'of', 'case', '35', 'atrocities'), ('34', 'mass', 'amod', '35', 'atrocities'), ('35', 'atrocities', 'nmod', '32', 'histories'), ('36', '.', 'punct', '10', 'labeled')]","'Mia': 1
# 'Farrow': 2
# ',': 3
# 'a': 4
# 'UN': 5
# 'goodwill': 6
# 'ambassador': 7
# ',': 8
# 'has': 9
# 'labeled': 10
# 'the': 11
# 'Beijing': 12
# 'Games': 13
# 'the': 14
# '""': 15
# 'genocide': 16
# 'Olympics': 17
# '""': 18
# 'and': 19
# 'has': 20
# 'launched': 21
# 'her': 22
# 'own': 23
# 'Olympic': 24
# '-': 25
# 'style': 26
# 'torch': 27
# 'relay': 28
# 'through': 29
# 'countries': 30
# 'with': 31
# 'histories': 32
# 'of': 33
# 'mass': 34
# 'atrocities': 35
# '.': 36"
# 9,"""The board must not only be free of partisanship, but must function so all of the members have access"" to allegations of misconduct, said Rep Juanita Millender-McDonald, a Democrat and chairman of the Committee on House Administration.",Committee on House Administration,Juanita Millender-McDonald,"[('1', '""', 'punct', '28', 'said'), ('2', 'The', 'det', '3', 'board'), ('3', 'board', 'nsubj', '8', 'free'), ('4', 'must', 'aux', '8', 'free'), ('5', 'not', 'advmod', '8', 'free'), ('6', 'only', 'advmod', '8', 'free'), ('7', 'be', 'cop', '8', 'free'), ('8', 'free', 'ccomp', '28', 'said'), ('9', 'of', 'case', '10', 'partisanship'), ('10', 'partisanship', 'obl', '8', 'free'), ('11', ',', 'punct', '14', 'function'), ('12', 'but', 'cc', '14', 'function'), ('13', 'must', 'aux', '14', 'function'), ('14', 'function', 'conj', '8', 'free'), ('15', 'so', 'advmod', '20', 'have'), ('16', 'all', 'nsubj', '20', 'have'), ('17', 'of', 'case', '19', 'members'), ('18', 'the', 'det', '19', 'members'), ('19', 'members', 'nmod', '16', 'all'), ('20', 'have', 'advcl', '14', 'function'), ('21', 'access', 'obj', '20', 'have'), ('22', '""', 'punct', '21', 'access'), ('23', 'to', 'case', '24', 'allegations'), ('24', 'allegations', 'nmod', '21', 'access'), ('25', 'of', 'case', '26', 'misconduct'), ('26', 'misconduct', 'nmod', '24', 'allegations'), ('27', ',', 'punct', '28', 'said'), ('28', 'said', 'root', '0', 'ROOT'), ('29', 'Rep', 'nsubj', '28', 'said'), ('30', 'Juanita', 'flat', '29', 'Rep'), ('31', 'Millender', 'flat', '29', 'Rep'), ('32', '-', 'punct', '29', 'Rep'), ('33', 'McDonald', 'flat', '29', 'Rep'), ('34', ',', 'punct', '29', 'Rep'), ('35', 'a', 'det', '36', 'Democrat'), ('36', 'Democrat', 'appos', '29', 'Rep'), ('37', 'and', 'cc', '38', 'chairman'), ('38', 'chairman', 'conj', '36', 'Democrat'), ('39', 'of', 'case', '41', 'Committee'), ('40', 'the', 'det', '41', 'Committee'), ('41', 'Committee', 'nmod', '38', 'chairman'), ('42', 'on', 'case', '44', 'Administration'), ('43', 'House', 'compound', '44', 'Administration'), ('44', 'Administration', 'nmod', '41', 'Committee'), ('45', '.', 'punct', '28', 'said')]","'""': 1
# 'The': 2
# 'board': 3
# 'must': 4
# 'not': 5
# 'only': 6
# 'be': 7
# 'free': 8
# 'of': 9
# 'partisanship': 10
# ',': 11
# 'but': 12
# 'must': 13
# 'function': 14
# 'so': 15
# 'all': 16
# 'of': 17
# 'the': 18
# 'members': 19
# 'have': 20
# 'access': 21
# '""': 22
# 'to': 23
# 'allegations': 24
# 'of': 25
# 'misconduct': 26
# ',': 27
# 'said': 28
# 'Rep': 29
# 'Juanita': 30
# 'Millender': 31
# '-': 32
# 'McDonald': 33
# ',': 34
# 'a': 35
# 'Democrat': 36
# 'and': 37
# 'chairman': 38
# 'of': 39
# 'the': 40
# 'Committee': 41
# 'on': 42
# 'House': 43
# 'Administration': 44
# '.': 45"
# 10,"The ""Forgotten Americans Coalition"" is composed of a number of veteran conservative leaders, including the American Family Association's Dr. Don Wildmon, Christian Broadcasting Network's Robertson, the Free Congress Foundation's Paul Weyrich, and Tim LaHaye, the co-author of the wildly popular ""Left Behind"" series of apocalyptic novels, and his wife, Beverly, the founder of Concerned Women for America.",American Family Association,Don Wildmon,"[('1', 'The', 'det', '5', 'Coalition'), ('2', '""', 'punct', '5', 'Coalition'), ('3', 'Forgotten', 'compound', '5', 'Coalition'), ('4', 'Americans', 'compound', '5', 'Coalition'), ('5', 'Coalition', 'nsubj:pass', '8', 'composed'), ('6', '""', 'punct', '5', 'Coalition'), ('7', 'is', 'aux:pass', '8', 'composed'), ('8', 'composed', 'root', '0', 'ROOT'), ('9', 'of', 'case', '11', 'number'), ('10', 'a', 'det', '11', 'number'), ('11', 'number', 'obl', '8', 'composed'), ('12', 'of', 'case', '15', 'leaders'), ('13', 'veteran', 'amod', '15', 'leaders'), ('14', 'conservative', 'amod', '15', 'leaders'), ('15', 'leaders', 'nmod', '11', 'number'), ('16', ',', 'punct', '15', 'leaders'), ('17', 'including', 'case', '23', 'Dr.'), ('18', 'the', 'det', '21', 'Association'), ('19', 'American', 'compound', '21', 'Association'), ('20', 'Family', 'compound', '21', 'Association'), ('21', 'Association', 'nmod:poss', '23', 'Dr.'), ('22', ""'s"", 'case', '21', 'Association'), ('23', 'Dr.', 'nmod', '11', 'number'), ('24', 'Don', 'flat', '23', 'Dr.'), ('25', 'Wildmon', 'flat', '23', 'Dr.'), ('26', ',', 'punct', '31', 'Robertson'), ('27', 'Christian', 'compound', '29', 'Network'), ('28', 'Broadcasting', 'compound', '29', 'Network'), ('29', 'Network', 'nmod:poss', '31', 'Robertson'), ('30', ""'s"", 'case', '29', 'Network'), ('31', 'Robertson', 'appos', '23', 'Dr.'), ('32', ',', 'punct', '38', 'Paul'), ('33', 'the', 'det', '36', 'Foundation'), ('34', 'Free', 'amod', '36', 'Foundation'), ('35', 'Congress', 'compound', '36', 'Foundation'), ('36', 'Foundation', 'nmod:poss', '38', 'Paul'), ('37', ""'s"", 'case', '36', 'Foundation'), ('38', 'Paul', 'appos', '31', 'Robertson'), ('39', 'Weyrich', 'flat', '38', 'Paul'), ('40', ',', 'punct', '42', 'Tim'), ('41', 'and', 'cc', '42', 'Tim'), ('42', 'Tim', 'conj', '23', 'Dr.'), ('43', 'LaHaye', 'flat', '42', 'Tim'), ('44', ',', 'punct', '42', 'Tim'), ('45', 'the', 'det', '46', 'co-author'), ('46', 'co-author', 'appos', '42', 'Tim'), ('47', 'of', 'case', '55', 'series'), ('48', 'the', 'det', '55', 'series'), ('49', 'wildly', 'advmod', '50', 'popular'), ('50', 'popular', 'amod', '55', 'series'), ('51', '""', 'punct', '52', 'Left'), ('52', 'Left', 'compound', '55', 'series'), ('53', 'Behind', 'case', '52', 'Left'), ('54', '""', 'punct', '52', 'Left'), ('55', 'series', 'nmod', '46', 'co-author'), ('56', 'of', 'case', '58', 'novels'), ('57', 'apocalyptic', 'amod', '58', 'novels'), ('58', 'novels', 'nmod', '55', 'series'), ('59', ',', 'punct', '62', 'wife'), ('60', 'and', 'cc', '62', 'wife'), ('61', 'his', 'nmod:poss', '62', 'wife'), ('62', 'wife', 'conj', '58', 'novels'), ('63', ',', 'punct', '62', 'wife'), ('64', 'Beverly', 'appos', '62', 'wife'), ('65', ',', 'punct', '62', 'wife'), ('66', 'the', 'det', '67', 'founder'), ('67', 'founder', 'appos', '62', 'wife'), ('68', 'of', 'case', '70', 'Women'), ('69', 'Concerned', 'amod', '70', 'Women'), ('70', 'Women', 'nmod', '67', 'founder'), ('71', 'for', 'case', '72', 'America'), ('72', 'America', 'nmod', '70', 'Women'), ('73', '.', 'punct', '8', 'composed')]","'The': 1
# '""': 2
# 'Forgotten': 3
# 'Americans': 4
# 'Coalition': 5
# '""': 6
# 'is': 7
# 'composed': 8
# 'of': 9
# 'a': 10
# 'number': 11
# 'of': 12
# 'veteran': 13
# 'conservative': 14
# 'leaders': 15
# ',': 16
# 'including': 17
# 'the': 18
# 'American': 19
# 'Family': 20
# 'Association': 21
# ''s': 22
# 'Dr.': 23
# 'Don': 24
# 'Wildmon': 25
# ',': 26
# 'Christian': 27
# 'Broadcasting': 28
# 'Network': 29
# ''s': 30
# 'Robertson': 31
# ',': 32
# 'the': 33
# 'Free': 34
# 'Congress': 35
# 'Foundation': 36
# ''s': 37
# 'Paul': 38
# 'Weyrich': 39
# ',': 40
# 'and': 41
# 'Tim': 42
# 'LaHaye': 43
# ',': 44
# 'the': 45
# 'co-author': 46
# 'of': 47
# 'the': 48
# 'wildly': 49
# 'popular': 50
# '""': 51
# 'Left': 52
# 'Behind': 53
# '""': 54
# 'series': 55
# 'of': 56
# 'apocalyptic': 57
# 'novels': 58
# ',': 59
# 'and': 60
# 'his': 61
# 'wife': 62
# ',': 63
# 'Beverly': 64
# ',': 65
# 'the': 66
# 'founder': 67
# 'of': 68
# 'Concerned': 69
# 'Women': 70
# 'for': 71
# 'America': 72
# '.': 73"
# 11,"Vice President Ali Akbar Salehi, who is also the head of Atomic Energy Organization of Iran, said world powers would discredit themselves if they passed new sanctions.",Atomic Energy Organization of Iran,Ali Akbar Salehi,"[('1', 'Vice', 'compound', '2', 'President'), ('2', 'President', 'nsubj', '19', 'said'), ('3', 'Ali', 'flat', '2', 'President'), ('4', 'Akbar', 'flat', '2', 'President'), ('5', 'Salehi', 'flat', '2', 'President'), ('6', ',', 'punct', '2', 'President'), ('7', 'who', 'nsubj', '11', 'head'), ('8', 'is', 'cop', '11', 'head'), ('9', 'also', 'advmod', '11', 'head'), ('10', 'the', 'det', '11', 'head'), ('11', 'head', 'acl:relcl', '2', 'President'), ('12', 'of', 'case', '15', 'Organization'), ('13', 'Atomic', 'compound', '15', 'Organization'), ('14', 'Energy', 'compound', '15', 'Organization'), ('15', 'Organization', 'nmod', '11', 'head'), ('16', 'of', 'case', '17', 'Iran'), ('17', 'Iran', 'nmod', '15', 'Organization'), ('18', ',', 'punct', '19', 'said'), ('19', 'said', 'root', '0', 'ROOT'), ('20', 'world', 'compound', '21', 'powers'), ('21', 'powers', 'nsubj', '23', 'discredit'), ('22', 'would', 'aux', '23', 'discredit'), ('23', 'discredit', 'ccomp', '19', 'said'), ('24', 'themselves', 'obj', '23', 'discredit'), ('25', 'if', 'mark', '27', 'passed'), ('26', 'they', 'nsubj', '27', 'passed'), ('27', 'passed', 'advcl', '23', 'discredit'), ('28', 'new', 'amod', '29', 'sanctions'), ('29', 'sanctions', 'obj', '27', 'passed'), ('30', '.', 'punct', '19', 'said')]","'Vice': 1
# 'President': 2
# 'Ali': 3
# 'Akbar': 4
# 'Salehi': 5
# ',': 6
# 'who': 7
# 'is': 8
# 'also': 9
# 'the': 10
# 'head': 11
# 'of': 12
# 'Atomic': 13
# 'Energy': 14
# 'Organization': 15
# 'of': 16
# 'Iran': 17
# ',': 18
# 'said': 19
# 'world': 20
# 'powers': 21
# 'would': 22
# 'discredit': 23
# 'themselves': 24
# 'if': 25
# 'they': 26
# 'passed': 27
# 'new': 28
# 'sanctions': 29
# '.': 30"
# 12,He was an Army veteran of the Korean War.,Army,He,"[('1', 'He', 'nsubj', '5', 'veteran'), ('2', 'was', 'cop', '5', 'veteran'), ('3', 'an', 'det', '5', 'veteran'), ('4', 'Army', 'compound', '5', 'veteran'), ('5', 'veteran', 'root', '0', 'ROOT'), ('6', 'of', 'case', '9', 'War.'), ('7', 'the', 'det', '9', 'War.'), ('8', 'Korean', 'compound', '9', 'War.'), ('9', 'War.', 'nmod', '5', 'veteran')]","'He': 1
# 'was': 2
# 'an': 3
# 'Army': 4
# 'veteran': 5
# 'of': 6
# 'the': 7
# 'Korean': 8
# 'War.': 9"
# 13,"Over his eight terms, in addition to heading the Small Business Committee, he was also Democratic whip at large, the senior member of the House Banking, Finance and Urban Affairs Committee, and chairman of its Subcommittee on Domestic Monetary Policy.",Small Business Committee,he,"[('1', 'Over', 'case', '4', 'terms'), ('2', 'his', 'nmod:poss', '4', 'terms'), ('3', 'eight', 'nummod', '4', 'terms'), ('4', 'terms', 'obl', '19', 'whip'), ('5', ',', 'punct', '19', 'whip'), ('6', 'in', 'case', '7', 'addition'), ('7', 'addition', 'obl', '19', 'whip'), ('8', 'to', 'mark', '9', 'heading'), ('9', 'heading', 'acl', '7', 'addition'), ('10', 'the', 'det', '13', 'Committee'), ('11', 'Small', 'compound', '13', 'Committee'), ('12', 'Business', 'compound', '13', 'Committee'), ('13', 'Committee', 'obj', '9', 'heading'), ('14', ',', 'punct', '19', 'whip'), ('15', 'he', 'nsubj', '19', 'whip'), ('16', 'was', 'cop', '19', 'whip'), ('17', 'also', 'advmod', '19', 'whip'), ('18', 'Democratic', 'amod', '19', 'whip'), ('19', 'whip', 'root', '0', 'ROOT'), ('20', 'at', 'case', '21', 'large'), ('21', 'large', 'nmod', '19', 'whip'), ('22', ',', 'punct', '19', 'whip'), ('23', 'the', 'det', '25', 'member'), ('24', 'senior', 'amod', '25', 'member'), ('25', 'member', 'conj', '19', 'whip'), ('26', 'of', 'case', '29', 'Banking'), ('27', 'the', 'det', '29', 'Banking'), ('28', 'House', 'compound', '29', 'Banking'), ('29', 'Banking', 'nmod', '25', 'member'), ('30', ',', 'punct', '31', 'Finance'), ('31', 'Finance', 'conj', '29', 'Banking'), ('32', 'and', 'cc', '34', 'Affairs'), ('33', 'Urban', 'compound', '34', 'Affairs'), ('34', 'Affairs', 'compound', '35', 'Committee'), ('35', 'Committee', 'conj', '29', 'Banking'), ('36', ',', 'punct', '38', 'chairman'), ('37', 'and', 'cc', '38', 'chairman'), ('38', 'chairman', 'conj', '25', 'member'), ('39', 'of', 'case', '41', 'Subcommittee'), ('40', 'its', 'nmod:poss', '41', 'Subcommittee'), ('41', 'Subcommittee', 'nmod', '38', 'chairman'), ('42', 'on', 'case', '45', 'Policy'), ('43', 'Domestic', 'compound', '45', 'Policy'), ('44', 'Monetary', 'compound', '45', 'Policy'), ('45', 'Policy', 'nmod', '41', 'Subcommittee'), ('46', '.', 'punct', '19', 'whip')]","'Over': 1
# 'his': 2
# 'eight': 3
# 'terms': 4
# ',': 5
# 'in': 6
# 'addition': 7
# 'to': 8
# 'heading': 9
# 'the': 10
# 'Small': 11
# 'Business': 12
# 'Committee': 13
# ',': 14
# 'he': 15
# 'was': 16
# 'also': 17
# 'Democratic': 18
# 'whip': 19
# 'at': 20
# 'large': 21
# ',': 22
# 'the': 23
# 'senior': 24
# 'member': 25
# 'of': 26
# 'the': 27
# 'House': 28
# 'Banking': 29
# ',': 30
# 'Finance': 31
# 'and': 32
# 'Urban': 33
# 'Affairs': 34
# 'Committee': 35
# ',': 36
# 'and': 37
# 'chairman': 38
# 'of': 39
# 'its': 40
# 'Subcommittee': 41
# 'on': 42
# 'Domestic': 43
# 'Monetary': 44
# 'Policy': 45
# '.': 46"
# 14,"A ruling Democratic Progressive Party legislator demanded Monday that Defense Minister Lee Jye ""give the country an explanation"" over allegations of the widespread existence of sexual harassment in the military.",Defense,Lee Jye,"[('1', 'A', 'det', '6', 'legislator'), ('2', 'ruling', 'compound', '6', 'legislator'), ('3', 'Democratic', 'compound', '5', 'Party'), ('4', 'Progressive', 'compound', '5', 'Party'), ('5', 'Party', 'compound', '6', 'legislator'), ('6', 'legislator', 'nsubj', '7', 'demanded'), ('7', 'demanded', 'root', '0', 'ROOT'), ('8', 'Monday', 'obl:tmod', '7', 'demanded'), ('9', 'that', 'mark', '15', 'give'), ('10', 'Defense', 'compound', '11', 'Minister'), ('11', 'Minister', 'nsubj', '15', 'give'), ('12', 'Lee', 'flat', '11', 'Minister'), ('13', 'Jye', 'flat', '11', 'Minister'), ('14', '""', 'punct', '15', 'give'), ('15', 'give', 'ccomp', '7', 'demanded'), ('16', 'the', 'det', '17', 'country'), ('17', 'country', 'iobj', '15', 'give'), ('18', 'an', 'det', '19', 'explanation'), ('19', 'explanation', 'obj', '15', 'give'), ('20', '""', 'punct', '19', 'explanation'), ('21', 'over', 'case', '22', 'allegations'), ('22', 'allegations', 'obl', '15', 'give'), ('23', 'of', 'case', '26', 'existence'), ('24', 'the', 'det', '26', 'existence'), ('25', 'widespread', 'amod', '26', 'existence'), ('26', 'existence', 'nmod', '22', 'allegations'), ('27', 'of', 'case', '29', 'harassment'), ('28', 'sexual', 'amod', '29', 'harassment'), ('29', 'harassment', 'nmod', '26', 'existence'), ('30', 'in', 'case', '32', 'military'), ('31', 'the', 'det', '32', 'military'), ('32', 'military', 'nmod', '26', 'existence'), ('33', '.', 'punct', '7', 'demanded')]","'A': 1
# 'ruling': 2
# 'Democratic': 3
# 'Progressive': 4
# 'Party': 5
# 'legislator': 6
# 'demanded': 7
# 'Monday': 8
# 'that': 9
# 'Defense': 10
# 'Minister': 11
# 'Lee': 12
# 'Jye': 13
# '""': 14
# 'give': 15
# 'the': 16
# 'country': 17
# 'an': 18
# 'explanation': 19
# '""': 20
# 'over': 21
# 'allegations': 22
# 'of': 23
# 'the': 24
# 'widespread': 25
# 'existence': 26
# 'of': 27
# 'sexual': 28
# 'harassment': 29
# 'in': 30
# 'the': 31
# 'military': 32
# '.': 33"
# 15,"JetBlue Airways Corp spokesman Bryan Baldwin said he was ""not privy to conversations"" that the board members have had about Neeleman.",JetBlue Airways Corp,Bryan Baldwin,"[('1', 'JetBlue', 'compound', '4', 'spokesman'), ('2', 'Airways', 'compound', '4', 'spokesman'), ('3', 'Corp', 'compound', '4', 'spokesman'), ('4', 'spokesman', 'compound', '5', 'Bryan'), ('5', 'Bryan', 'nsubj', '7', 'said'), ('6', 'Baldwin', 'flat', '5', 'Bryan'), ('7', 'said', 'root', '0', 'ROOT'), ('8', 'he', 'nsubj', '12', 'privy'), ('9', 'was', 'cop', '12', 'privy'), ('10', '""', 'punct', '12', 'privy'), ('11', 'not', 'advmod', '12', 'privy'), ('12', 'privy', 'ccomp', '7', 'said'), ('13', 'to', 'case', '14', 'conversations'), ('14', 'conversations', 'obl', '12', 'privy'), ('15', '""', 'punct', '12', 'privy'), ('16', 'that', 'obj', '21', 'had'), ('17', 'the', 'det', '19', 'members'), ('18', 'board', 'compound', '19', 'members'), ('19', 'members', 'nsubj', '21', 'had'), ('20', 'have', 'aux', '21', 'had'), ('21', 'had', 'acl:relcl', '14', 'conversations'), ('22', 'about', 'case', '23', 'Neeleman'), ('23', 'Neeleman', 'obl', '21', 'had'), ('24', '.', 'punct', '7', 'said')]","'JetBlue': 1
# 'Airways': 2
# 'Corp': 3
# 'spokesman': 4
# 'Bryan': 5
# 'Baldwin': 6
# 'said': 7
# 'he': 8
# 'was': 9
# '""': 10
# 'not': 11
# 'privy': 12
# 'to': 13
# 'conversations': 14
# '""': 15
# 'that': 16
# 'the': 17
# 'board': 18
# 'members': 19
# 'have': 20
# 'had': 21
# 'about': 22
# 'Neeleman': 23
# '.': 24"
# 16,"He's stayed ""red"" through his two terms in office: Livingstone called Fidel Castro's communist revolution ""one of the high points of the 20th century ,"" and welcomed Venezuelan president Hugo Chavez to city hall.",Venezuelan,Hugo Chavez,"[('1', 'He', 'nsubj:pass', '3', 'stayed'), ('2', ""'s"", 'aux:pass', '3', 'stayed'), ('3', 'stayed', 'root', '0', 'ROOT'), ('4', '""', 'punct', '5', 'red'), ('5', 'red', 'xcomp', '3', 'stayed'), ('6', '""', 'punct', '5', 'red'), ('7', 'through', 'case', '10', 'terms'), ('8', 'his', 'nmod:poss', '10', 'terms'), ('9', 'two', 'nummod', '10', 'terms'), ('10', 'terms', 'obl', '3', 'stayed'), ('11', 'in', 'case', '12', 'office'), ('12', 'office', 'nmod', '10', 'terms'), ('13', ':', 'punct', '3', 'stayed'), ('14', 'Livingstone', 'nsubj', '15', 'called'), ('15', 'called', 'parataxis', '3', 'stayed'), ('16', 'Fidel', 'nmod:poss', '20', 'revolution'), ('17', 'Castro', 'flat', '16', 'Fidel'), ('18', ""'s"", 'case', '16', 'Fidel'), ('19', 'communist', 'amod', '20', 'revolution'), ('20', 'revolution', 'obj', '15', 'called'), ('21', '""', 'punct', '22', 'one'), ('22', 'one', 'appos', '20', 'revolution'), ('23', 'of', 'case', '26', 'points'), ('24', 'the', 'det', '26', 'points'), ('25', 'high', 'amod', '26', 'points'), ('26', 'points', 'nmod', '22', 'one'), ('27', 'of', 'case', '30', 'century'), ('28', 'the', 'det', '30', 'century'), ('29', '20th', 'amod', '30', 'century'), ('30', 'century', 'nmod', '26', 'points'), ('31', ',', 'punct', '34', 'welcomed'), ('32', '""', 'punct', '22', 'one'), ('33', 'and', 'cc', '34', 'welcomed'), ('34', 'welcomed', 'conj', '15', 'called'), ('35', 'Venezuelan', 'amod', '36', 'president'), ('36', 'president', 'obj', '34', 'welcomed'), ('37', 'Hugo', 'flat', '36', 'president'), ('38', 'Chavez', 'flat', '36', 'president'), ('39', 'to', 'case', '41', 'hall'), ('40', 'city', 'compound', '41', 'hall'), ('41', 'hall', 'obl', '34', 'welcomed'), ('42', '.', 'punct', '3', 'stayed')]","'He': 1
# ''s': 2
# 'stayed': 3
# '""': 4
# 'red': 5
# '""': 6
# 'through': 7
# 'his': 8
# 'two': 9
# 'terms': 10
# 'in': 11
# 'office': 12
# ':': 13
# 'Livingstone': 14
# 'called': 15
# 'Fidel': 16
# 'Castro': 17
# ''s': 18
# 'communist': 19
# 'revolution': 20
# '""': 21
# 'one': 22
# 'of': 23
# 'the': 24
# 'high': 25
# 'points': 26
# 'of': 27
# 'the': 28
# '20th': 29
# 'century': 30
# ',': 31
# '""': 32
# 'and': 33
# 'welcomed': 34
# 'Venezuelan': 35
# 'president': 36
# 'Hugo': 37
# 'Chavez': 38
# 'to': 39
# 'city': 40
# 'hall': 41
# '.': 42"
# 17,"And publicly today the White House is taking the optimistic route, Press Secretary Dee Dee Myers predicting the Democrats will be able to hold onto control of Congress, and she's predicting that they will have the traditional losses that the party in power usually has during these mid-term elections.",White House,Dee Dee Myers,"[('1', 'And', 'cc', '8', 'taking'), ('2', 'publicly', 'advmod', '8', 'taking'), ('3', 'today', 'obl:tmod', '8', 'taking'), ('4', 'the', 'det', '6', 'House'), ('5', 'White', 'compound', '6', 'House'), ('6', 'House', 'nsubj', '8', 'taking'), ('7', 'is', 'aux', '8', 'taking'), ('8', 'taking', 'root', '0', 'ROOT'), ('9', 'the', 'det', '11', 'route'), ('10', 'optimistic', 'amod', '11', 'route'), ('11', 'route', 'obj', '8', 'taking'), ('12', ',', 'punct', '11', 'route'), ('13', 'Press', 'compound', '14', 'Secretary'), ('14', 'Secretary', 'compound', '15', 'Dee'), ('15', 'Dee', 'appos', '11', 'route'), ('16', 'Dee', 'flat', '15', 'Dee'), ('17', 'Myers', 'flat', '15', 'Dee'), ('18', 'predicting', 'advcl', '8', 'taking'), ('19', 'the', 'det', '20', 'Democrats'), ('20', 'Democrats', 'nsubj', '23', 'able'), ('21', 'will', 'aux', '23', 'able'), ('22', 'be', 'cop', '23', 'able'), ('23', 'able', 'ccomp', '18', 'predicting'), ('24', 'to', 'mark', '25', 'hold'), ('25', 'hold', 'xcomp', '23', 'able'), ('26', 'onto', 'case', '27', 'control'), ('27', 'control', 'obl', '25', 'hold'), ('28', 'of', 'case', '29', 'Congress'), ('29', 'Congress', 'nmod', '27', 'control'), ('30', ',', 'punct', '34', 'predicting'), ('31', 'and', 'cc', '34', 'predicting'), ('32', 'she', 'nsubj', '34', 'predicting'), ('33', ""'s"", 'aux', '34', 'predicting'), ('34', 'predicting', 'conj', '8', 'taking'), ('35', 'that', 'mark', '38', 'have'), ('36', 'they', 'nsubj', '38', 'have'), ('37', 'will', 'aux', '38', 'have'), ('38', 'have', 'ccomp', '34', 'predicting'), ('39', 'the', 'det', '41', 'losses'), ('40', 'traditional', 'amod', '41', 'losses'), ('41', 'losses', 'obj', '38', 'have'), ('42', 'that', 'obj', '48', 'has'), ('43', 'the', 'det', '44', 'party'), ('44', 'party', 'nsubj', '48', 'has'), ('45', 'in', 'case', '46', 'power'), ('46', 'power', 'nmod', '44', 'party'), ('47', 'usually', 'advmod', '48', 'has'), ('48', 'has', 'acl:relcl', '41', 'losses'), ('49', 'during', 'case', '52', 'elections'), ('50', 'these', 'det', '52', 'elections'), ('51', 'mid-term', 'amod', '52', 'elections'), ('52', 'elections', 'obl', '48', 'has'), ('53', '.', 'punct', '8', 'taking')]","'And': 1
# 'publicly': 2
# 'today': 3
# 'the': 4
# 'White': 5
# 'House': 6
# 'is': 7
# 'taking': 8
# 'the': 9
# 'optimistic': 10
# 'route': 11
# ',': 12
# 'Press': 13
# 'Secretary': 14
# 'Dee': 15
# 'Dee': 16
# 'Myers': 17
# 'predicting': 18
# 'the': 19
# 'Democrats': 20
# 'will': 21
# 'be': 22
# 'able': 23
# 'to': 24
# 'hold': 25
# 'onto': 26
# 'control': 27
# 'of': 28
# 'Congress': 29
# ',': 30
# 'and': 31
# 'she': 32
# ''s': 33
# 'predicting': 34
# 'that': 35
# 'they': 36
# 'will': 37
# 'have': 38
# 'the': 39
# 'traditional': 40
# 'losses': 41
# 'that': 42
# 'the': 43
# 'party': 44
# 'in': 45
# 'power': 46
# 'usually': 47
# 'has': 48
# 'during': 49
# 'these': 50
# 'mid-term': 51
# 'elections': 52
# '.': 53"
# 18,"Until earlier this year, she worked on international trade issues for the Washington office of DLA Piper, one of the city's biggest lobbying firms.",DLA Piper,she,"[('1', 'Until', 'case', '4', 'year'), ('2', 'earlier', 'advmod', '4', 'year'), ('3', 'this', 'det', '4', 'year'), ('4', 'year', 'obl:tmod', '7', 'worked'), ('5', ',', 'punct', '7', 'worked'), ('6', 'she', 'nsubj', '7', 'worked'), ('7', 'worked', 'root', '0', 'ROOT'), ('8', 'on', 'case', '11', 'issues'), ('9', 'international', 'amod', '11', 'issues'), ('10', 'trade', 'compound', '11', 'issues'), ('11', 'issues', 'obl', '7', 'worked'), ('12', 'for', 'case', '15', 'office'), ('13', 'the', 'det', '15', 'office'), ('14', 'Washington', 'compound', '15', 'office'), ('15', 'office', 'nmod', '11', 'issues'), ('16', 'of', 'case', '18', 'Piper'), ('17', 'DLA', 'nmod', '15', 'office'), ('18', 'Piper', 'nmod', '15', 'office'), ('19', ',', 'punct', '15', 'office'), ('20', 'one', 'appos', '15', 'office'), ('21', 'of', 'case', '27', 'firms'), ('22', 'the', 'det', '23', 'city'), ('23', 'city', 'nmod:poss', '27', 'firms'), ('24', ""'s"", 'case', '23', 'city'), ('25', 'biggest', 'amod', '27', 'firms'), ('26', 'lobbying', 'compound', '27', 'firms'), ('27', 'firms', 'nmod', '20', 'one'), ('28', '.', 'punct', '7', 'worked')]","'Until': 1
# 'earlier': 2
# 'this': 3
# 'year': 4
# ',': 5
# 'she': 6
# 'worked': 7
# 'on': 8
# 'international': 9
# 'trade': 10
# 'issues': 11
# 'for': 12
# 'the': 13
# 'Washington': 14
# 'office': 15
# 'of': 16
# 'DLA': 17
# 'Piper': 18
# ',': 19
# 'one': 20
# 'of': 21
# 'the': 22
# 'city': 23
# ''s': 24
# 'biggest': 25
# 'lobbying': 26
# 'firms': 27
# '.': 28"
# 19,"Cathie Black, president of Hearst Magazines, is the author of ""Basic Black: The Essential Guide for Getting Ahead At Work (and in Life).""",Hearst Magazines,Cathie Black,"[('1', 'Cathie', 'nsubj', '11', 'author'), ('2', 'Black', 'flat', '1', 'Cathie'), ('3', ',', 'punct', '1', 'Cathie'), ('4', 'president', 'appos', '1', 'Cathie'), ('5', 'of', 'case', '7', 'Magazines'), ('6', 'Hearst', 'compound', '7', 'Magazines'), ('7', 'Magazines', 'nmod', '4', 'president'), ('8', ',', 'punct', '11', 'author'), ('9', 'is', 'cop', '11', 'author'), ('10', 'the', 'det', '11', 'author'), ('11', 'author', 'root', '0', 'ROOT'), ('12', 'of', 'case', '15', 'Black'), ('13', '""', 'punct', '15', 'Black'), ('14', 'Basic', 'compound', '15', 'Black'), ('15', 'Black', 'nmod', '11', 'author'), ('16', ':', 'punct', '15', 'Black'), ('17', 'The', 'det', '19', 'Guide'), ('18', 'Essential', 'compound', '19', 'Guide'), ('19', 'Guide', 'appos', '15', 'Black'), ('20', 'for', 'mark', '21', 'Getting'), ('21', 'Getting', 'acl', '19', 'Guide'), ('22', 'Ahead', 'advmod', '21', 'Getting'), ('23', 'At', 'case', '24', 'Work'), ('24', 'Work', 'obl', '21', 'Getting'), ('25', '(', 'punct', '24', 'Work'), ('26', 'and', 'cc', '28', 'Life'), ('27', 'in', 'case', '28', 'Life'), ('28', 'Life', 'conj', '24', 'Work'), ('29', ')', 'punct', '28', 'Life'), ('30', '.', 'punct', '11', 'author'), ('31', '""', 'punct', '11', 'author')]","'Cathie': 1
# 'Black': 2
# ',': 3
# 'president': 4
# 'of': 5
# 'Hearst': 6
# 'Magazines': 7
# ',': 8
# 'is': 9
# 'the': 10
# 'author': 11
# 'of': 12
# '""': 13
# 'Basic': 14
# 'Black': 15
# ':': 16
# 'The': 17
# 'Essential': 18
# 'Guide': 19
# 'for': 20
# 'Getting': 21
# 'Ahead': 22
# 'At': 23
# 'Work': 24
# '(': 25
# 'and': 26
# 'in': 27
# 'Life': 28
# ')': 29
# '.': 30
# '""': 31"
# 20,When Deaver left the White House in 1985 he formed his own consulting firm.,White House,Deaver,"[('1', 'When', 'mark', '3', 'left'), ('2', 'Deaver', 'nsubj', '3', 'left'), ('3', 'left', 'advcl', '10', 'formed'), ('4', 'the', 'det', '6', 'House'), ('5', 'White', 'compound', '6', 'House'), ('6', 'House', 'obj', '3', 'left'), ('7', 'in', 'case', '8', '1985'), ('8', '1985', 'obl', '3', 'left'), ('9', 'he', 'nsubj', '10', 'formed'), ('10', 'formed', 'root', '0', 'ROOT'), ('11', 'his', 'nmod:poss', '14', 'firm'), ('12', 'own', 'amod', '14', 'firm'), ('13', 'consulting', 'compound', '14', 'firm'), ('14', 'firm', 'obj', '10', 'formed'), ('15', '.', 'punct', '10', 'formed')]","'When': 1
# 'Deaver': 2
# 'left': 3
# 'the': 4
# 'White': 5
# 'House': 6
# 'in': 7
# '1985': 8
# 'he': 9
# 'formed': 10
# 'his': 11
# 'own': 12
# 'consulting': 13
# 'firm': 14
# '.': 15"
# 21,Zaccheroni replaces Ferrara at Juventus,Juventus,Ferrara,"[('1', 'Zaccheroni', 'nsubj', '2', 'replaces'), ('2', 'replaces', 'root', '0', 'ROOT'), ('3', 'Ferrara', 'obj', '2', 'replaces'), ('4', 'at', 'case', '5', 'Juventus'), ('5', 'Juventus', 'obl', '2', 'replaces')]","'Zaccheroni': 1
# 'replaces': 2
# 'Ferrara': 3
# 'at': 4
# 'Juventus': 5"
# 22,"Wal-Mart's announcement came one day after Rep. Paul Gillmor, R-Ohio, publicly revealed a company e-mail suggesting that Wal - Mart was preparing to get more involved in financial services.",Wal-Mart,Paul Gillmor,"[('1', 'Wal', 'compound', '5', 'announcement'), ('2', '-', 'punct', '3', 'Mart'), ('3', 'Mart', 'nmod:poss', '5', 'announcement'), ('4', ""'s"", 'case', '3', 'Mart'), ('5', 'announcement', 'nsubj', '6', 'came'), ('6', 'came', 'advcl', '19', 'revealed'), ('7', 'one', 'nummod', '8', 'day'), ('8', 'day', 'obl:tmod', '6', 'came'), ('9', 'after', 'case', '10', 'Rep.'), ('10', 'Rep.', 'obl', '19', 'revealed'), ('11', 'Paul', 'flat', '10', 'Rep.'), ('12', 'Gillmor', 'flat', '10', 'Rep.'), ('13', ',', 'punct', '10', 'Rep.'), ('14', 'R', 'flat', '10', 'Rep.'), ('15', '-', 'punct', '10', 'Rep.'), ('16', 'Ohio', 'flat', '10', 'Rep.'), ('17', ',', 'punct', '19', 'revealed'), ('18', 'publicly', 'advmod', '19', 'revealed'), ('19', 'revealed', 'root', '0', 'ROOT'), ('20', 'a', 'det', '22', 'e-mail'), ('21', 'company', 'compound', '22', 'e-mail'), ('22', 'e-mail', 'obj', '19', 'revealed'), ('23', 'suggesting', 'acl', '22', 'e-mail'), ('24', 'that', 'mark', '29', 'preparing'), ('25', 'Wal', 'compound', '27', 'Mart'), ('26', '-', 'punct', '27', 'Mart'), ('27', 'Mart', 'nsubj', '29', 'preparing'), ('28', 'was', 'aux', '29', 'preparing'), ('29', 'preparing', 'ccomp', '23', 'suggesting'), ('30', 'to', 'mark', '33', 'involved'), ('31', 'get', 'aux', '33', 'involved'), ('32', 'more', 'advmod', '33', 'involved'), ('33', 'involved', 'xcomp', '29', 'preparing'), ('34', 'in', 'case', '36', 'services'), ('35', 'financial', 'amod', '36', 'services'), ('36', 'services', 'obl', '33', 'involved'), ('37', '.', 'punct', '19', 'revealed')]","'Wal': 1
# '-': 2
# 'Mart': 3
# ''s': 4
# 'announcement': 5
# 'came': 6
# 'one': 7
# 'day': 8
# 'after': 9
# 'Rep.': 10
# 'Paul': 11
# 'Gillmor': 12
# ',': 13
# 'R': 14
# '-': 15
# 'Ohio': 16
# ',': 17
# 'publicly': 18
# 'revealed': 19
# 'a': 20
# 'company': 21
# 'e-mail': 22
# 'suggesting': 23
# 'that': 24
# 'Wal': 25
# '-': 26
# 'Mart': 27
# 'was': 28
# 'preparing': 29
# 'to': 30
# 'get': 31
# 'more': 32
# 'involved': 33
# 'in': 34
# 'financial': 35
# 'services': 36
# '.': 37"
# 23,"Greenpeace's EU agriculture policy director Marco Contiero was unimpressed as he handed over a 180,000-signature petition calling on the EU executive to stop the authorisation of GM rice made by German pharmaeutical giant Bayer.",Greenpeace,Marco Contiero,"[('1', 'Greenpeace', 'nmod:poss', '6', 'director'), ('2', ""'s"", 'case', '1', 'Greenpeace'), ('3', 'EU', 'compound', '6', 'director'), ('4', 'agriculture', 'compound', '6', 'director'), ('5', 'policy', 'compound', '6', 'director'), ('6', 'director', 'compound', '7', 'Marco'), ('7', 'Marco', 'nsubj', '10', 'unimpressed'), ('8', 'Contiero', 'flat', '7', 'Marco'), ('9', 'was', 'cop', '10', 'unimpressed'), ('10', 'unimpressed', 'root', '0', 'ROOT'), ('11', 'as', 'mark', '13', 'handed'), ('12', 'he', 'nsubj', '13', 'handed'), ('13', 'handed', 'advcl', '10', 'unimpressed'), ('14', 'over', 'compound:prt', '13', 'handed'), ('15', 'a', 'det', '19', 'petition'), ('16', '180,000', 'nummod', '18', 'signature'), ('17', '-', 'punct', '18', 'signature'), ('18', 'signature', 'compound', '19', 'petition'), ('19', 'petition', 'obj', '13', 'handed'), ('20', 'calling', 'acl', '19', 'petition'), ('21', 'on', 'case', '24', 'executive'), ('22', 'the', 'det', '24', 'executive'), ('23', 'EU', 'compound', '24', 'executive'), ('24', 'executive', 'obl', '20', 'calling'), ('25', 'to', 'mark', '26', 'stop'), ('26', 'stop', 'advcl', '20', 'calling'), ('27', 'the', 'det', '28', 'authorisation'), ('28', 'authorisation', 'obj', '26', 'stop'), ('29', 'of', 'case', '31', 'rice'), ('30', 'GM', 'compound', '31', 'rice'), ('31', 'rice', 'nmod', '28', 'authorisation'), ('32', 'made', 'acl', '31', 'rice'), ('33', 'by', 'case', '37', 'Bayer'), ('34', 'German', 'amod', '37', 'Bayer'), ('35', 'pharmaeutical', 'amod', '37', 'Bayer'), ('36', 'giant', 'compound', '37', 'Bayer'), ('37', 'Bayer', 'obl', '32', 'made'), ('38', '.', 'punct', '10', 'unimpressed')]","'Greenpeace': 1
# ''s': 2
# 'EU': 3
# 'agriculture': 4
# 'policy': 5
# 'director': 6
# 'Marco': 7
# 'Contiero': 8
# 'was': 9
# 'unimpressed': 10
# 'as': 11
# 'he': 12
# 'handed': 13
# 'over': 14
# 'a': 15
# '180,000': 16
# '-': 17
# 'signature': 18
# 'petition': 19
# 'calling': 20
# 'on': 21
# 'the': 22
# 'EU': 23
# 'executive': 24
# 'to': 25
# 'stop': 26
# 'the': 27
# 'authorisation': 28
# 'of': 29
# 'GM': 30
# 'rice': 31
# 'made': 32
# 'by': 33
# 'German': 34
# 'pharmaeutical': 35
# 'giant': 36
# 'Bayer': 37
# '.': 38"
# ...
# 'seat': 15
# 'in': 16
# '1986': 17
# ',': 18
# 'McCain': 19
# 'vaulted': 20
# 'into': 21
# 'it': 22
# '.': 23"
# 1266,"Ospel, who was criticised by Switzerland's President Pascal Couchepin earlier this year for his ""Pharaoh-like"" salary, will not stand for re-election at the bank's AGM on April 23 and will be replaced by UBS's general counsel, Peter Kurer.",UBS,Ospel,"[('1', 'Ospel', 'nsubj', '26', 'stand'), ('2', ',', 'punct', '1', 'Ospel'), ('3', 'who', 'nsubj:pass', '5', 'criticised'), ('4', 'was', 'aux:pass', '5', 'criticised'), ('5', 'criticised', 'acl:relcl', '1', 'Ospel'), ('6', 'by', 'case', '9', 'President'), ('7', 'Switzerland', 'nmod:poss', '9', 'President'), ('8', ""'s"", 'case', '7', 'Switzerland'), ('9', 'President', 'obl', '5', 'criticised'), ('10', 'Pascal', 'flat', '9', 'President'), ('11', 'Couchepin', 'flat', '9', 'President'), ('12', 'earlier', 'advmod', '14', 'year'), ('13', 'this', 'det', '14', 'year'), ('14', 'year', 'obl:tmod', '5', 'criticised'), ('15', 'for', 'case', '22', 'salary'), ('16', 'his', 'nmod:poss', '22', 'salary'), ('17', '""', 'punct', '18', 'Pharaoh'), ('18', 'Pharaoh', 'compound', '22', 'salary'), ('19', '-', 'punct', '18', 'Pharaoh'), ('20', 'like', 'case', '18', 'Pharaoh'), ('21', '""', 'punct', '18', 'Pharaoh'), ('22', 'salary', 'obl', '5', 'criticised'), ('23', ',', 'punct', '26', 'stand'), ('24', 'will', 'aux', '26', 'stand'), ('25', 'not', 'advmod', '26', 'stand'), ('26', 'stand', 'root', '0', 'ROOT'), ('27', 'for', 'case', '28', 're-election'), ('28', 're-election', 'obl', '26', 'stand'), ('29', 'at', 'case', '33', 'AGM'), ('30', 'the', 'det', '31', 'bank'), ('31', 'bank', 'nmod:poss', '33', 'AGM'), ('32', ""'s"", 'case', '31', 'bank'), ('33', 'AGM', 'obl', '26', 'stand'), ('34', 'on', 'case', '35', 'April'), ('35', 'April', 'obl', '26', 'stand'), ('36', '23', 'nummod', '35', 'April'), ('37', 'and', 'cc', '40', 'replaced'), ('38', 'will', 'aux', '40', 'replaced'), ('39', 'be', 'aux:pass', '40', 'replaced'), ('40', 'replaced', 'conj', '26', 'stand'), ('41', 'by', 'case', '45', 'counsel'), ('42', 'UBS', 'nmod:poss', '45', 'counsel'), ('43', ""'s"", 'case', '42', 'UBS'), ('44', 'general', 'amod', '45', 'counsel'), ('45', 'counsel', 'obl', '40', 'replaced'), ('46', ',', 'punct', '45', 'counsel'), ('47', 'Peter', 'appos', '45', 'counsel'), ('48', 'Kurer', 'flat', '47', 'Peter'), ('49', '.', 'punct', '26', 'stand')]","'Ospel': 1
# ',': 2
# 'who': 3
# 'was': 4
# 'criticised': 5
# 'by': 6
# 'Switzerland': 7
# ''s': 8
# 'President': 9
# 'Pascal': 10
# 'Couchepin': 11
# 'earlier': 12
# 'this': 13
# 'year': 14
# 'for': 15
# 'his': 16
# '""': 17
# 'Pharaoh': 18
# '-': 19
# 'like': 20
# '""': 21
# 'salary': 22
# ',': 23
# 'will': 24
# 'not': 25
# 'stand': 26
# 'for': 27
# 're-election': 28
# 'at': 29
# 'the': 30
# 'bank': 31
# ''s': 32
# 'AGM': 33
# 'on': 34
# 'April': 35
# '23': 36
# 'and': 37
# 'will': 38
# 'be': 39
# 'replaced': 40
# 'by': 41
# 'UBS': 42
# ''s': 43
# 'general': 44
# 'counsel': 45
# ',': 46
# 'Peter': 47
# 'Kurer': 48
# '.': 49"
# 1267,"Tancredo's request, relayed in a letter to Administration Committee Chairwoman Juanita Millender-McDonald, also a Democrat, revived his effort to change House rules to abolish the groups.",Administration Committee,Juanita Millender-McDonald,"[('1', 'Tancredo', 'nmod:poss', '3', 'request'), ('2', ""'s"", 'case', '1', 'Tancredo'), ('3', 'request', 'nsubj', '22', 'revived'), ('4', ',', 'punct', '3', 'request'), ('5', 'relayed', 'acl', '3', 'request'), ('6', 'in', 'case', '8', 'letter'), ('7', 'a', 'det', '8', 'letter'), ('8', 'letter', 'obl', '5', 'relayed'), ('9', 'to', 'case', '12', 'Chairwoman'), ('10', 'Administration', 'compound', '11', 'Committee'), ('11', 'Committee', 'compound', '12', 'Chairwoman'), ('12', 'Chairwoman', 'nmod', '8', 'letter'), ('13', 'Juanita', 'flat', '12', 'Chairwoman'), ('14', 'Millender', 'flat', '12', 'Chairwoman'), ('15', '-', 'punct', '12', 'Chairwoman'), ('16', 'McDonald', 'flat', '12', 'Chairwoman'), ('17', ',', 'punct', '12', 'Chairwoman'), ('18', 'also', 'advmod', '20', 'Democrat'), ('19', 'a', 'det', '20', 'Democrat'), ('20', 'Democrat', 'appos', '12', 'Chairwoman'), ('21', ',', 'punct', '22', 'revived'), ('22', 'revived', 'root', '0', 'ROOT'), ('23', 'his', 'nmod:poss', '24', 'effort'), ('24', 'effort', 'obj', '22', 'revived'), ('25', 'to', 'mark', '26', 'change'), ('26', 'change', 'acl', '24', 'effort'), ('27', 'House', 'compound', '28', 'rules'), ('28', 'rules', 'obj', '26', 'change'), ('29', 'to', 'mark', '30', 'abolish'), ('30', 'abolish', 'advcl', '26', 'change'), ('31', 'the', 'det', '32', 'groups'), ('32', 'groups', 'obj', '30', 'abolish'), ('33', '.', 'punct', '22', 'revived')]","'Tancredo': 1
# ''s': 2
# 'request': 3
# ',': 4
# 'relayed': 5
# 'in': 6
# 'a': 7
# 'letter': 8
# 'to': 9
# 'Administration': 10
# 'Committee': 11
# 'Chairwoman': 12
# 'Juanita': 13
# 'Millender': 14
# '-': 15
# 'McDonald': 16
# ',': 17
# 'also': 18
# 'a': 19
# 'Democrat': 20
# ',': 21
# 'revived': 22
# 'his': 23
# 'effort': 24
# 'to': 25
# 'change': 26
# 'House': 27
# 'rules': 28
# 'to': 29
# 'abolish': 30
# 'the': 31
# 'groups': 32
# '.': 33"
# 1268,"Last month, the International Atomic Energy Agency's chief, Mohamed ElBaradei, was given new information on Iran's ""new generation of centrifuges"" during talks in Tehran - a priority as the agency tries to establish how far along Iran is in developing the technology.",International Atomic Energy Agency,Mohamed ElBaradei,"[('1', 'Last', 'amod', '2', 'month'), ('2', 'month', 'obl:tmod', '16', 'given'), ('3', ',', 'punct', '16', 'given'), ('4', 'the', 'det', '8', 'Agency'), ('5', 'International', 'compound', '8', 'Agency'), ('6', 'Atomic', 'compound', '8', 'Agency'), ('7', 'Energy', 'compound', '8', 'Agency'), ('8', 'Agency', 'nmod:poss', '10', 'chief'), ('9', ""'s"", 'case', '8', 'Agency'), ('10', 'chief', 'nsubj:pass', '16', 'given'), ('11', ',', 'punct', '10', 'chief'), ('12', 'Mohamed', 'appos', '10', 'chief'), ('13', 'ElBaradei', 'flat', '12', 'Mohamed'), ('14', ',', 'punct', '16', 'given'), ('15', 'was', 'aux:pass', '16', 'given'), ('16', 'given', 'root', '0', 'ROOT'), ('17', 'new', 'amod', '18', 'information'), ('18', 'information', 'obj', '16', 'given'), ('19', 'on', 'case', '24', 'generation'), ('20', 'Iran', 'nmod:poss', '24', 'generation'), ('21', ""'s"", 'case', '20', 'Iran'), ('22', '""', 'punct', '24', 'generation'), ('23', 'new', 'amod', '24', 'generation'), ('24', 'generation', 'nmod', '18', 'information'), ('25', 'of', 'case', '26', 'centrifuges'), ('26', 'centrifuges', 'nmod', '24', 'generation'), ('27', '""', 'punct', '24', 'generation'), ('28', 'during', 'case', '29', 'talks'), ('29', 'talks', 'nmod', '24', 'generation'), ('30', 'in', 'case', '31', 'Tehran'), ('31', 'Tehran', 'nmod', '29', 'talks'), ('32', '-', 'punct', '24', 'generation'), ('33', 'a', 'det', '34', 'priority'), ('34', 'priority', 'appos', '18', 'information'), ('35', 'as', 'mark', '38', 'tries'), ('36', 'the', 'det', '37', 'agency'), ('37', 'agency', 'nsubj', '38', 'tries'), ('38', 'tries', 'acl', '34', 'priority'), ('39', 'to', 'mark', '40', 'establish'), ('40', 'establish', 'xcomp', '38', 'tries'), ('41', 'how', 'advmod', '42', 'far'), ('42', 'far', 'advmod', '45', 'is'), ('43', 'along', 'case', '44', 'Iran'), ('44', 'Iran', 'obl', '42', 'far'), ('45', 'is', 'ccomp', '40', 'establish'), ('46', 'in', 'mark', '47', 'developing'), ('47', 'developing', 'advcl', '45', 'is'), ('48', 'the', 'det', '49', 'technology'), ('49', 'technology', 'obj', '47', 'developing'), ('50', '.', 'punct', '16', 'given')]","'Last': 1
# 'month': 2
# ',': 3
# 'the': 4
# 'International': 5
# 'Atomic': 6
# 'Energy': 7
# 'Agency': 8
# ''s': 9
# 'chief': 10
# ',': 11
# 'Mohamed': 12
# 'ElBaradei': 13
# ',': 14
# 'was': 15
# 'given': 16
# 'new': 17
# 'information': 18
# 'on': 19
# 'Iran': 20
# ''s': 21
# '""': 22
# 'new': 23
# 'generation': 24
# 'of': 25
# 'centrifuges': 26
# '""': 27
# 'during': 28
# 'talks': 29
# 'in': 30
# 'Tehran': 31
# '-': 32
# 'a': 33
# 'priority': 34
# 'as': 35
# 'the': 36
# 'agency': 37
# 'tries': 38
# 'to': 39
# 'establish': 40
# 'how': 41
# 'far': 42
# 'along': 43
# 'Iran': 44
# 'is': 45
# 'in': 46
# 'developing': 47
# 'the': 48
# 'technology': 49
# '.': 50"
# 1269,"Perhaps he'd ask the same if told that a U.S. attack on Iran will (as IAEA chief ElBaradei recently put it), transform the Middle East into ""a ball of fire.""",IAEA,ElBaradei,"[('1', 'Perhaps', 'advmod', '4', 'ask'), ('2', 'he', 'nsubj', '4', 'ask'), ('3', ""'d"", 'aux', '4', 'ask'), ('4', 'ask', 'root', '0', 'ROOT'), ('5', 'the', 'det', '6', 'same'), ('6', 'same', 'obj', '4', 'ask'), ('7', 'if', 'mark', '8', 'told'), ('8', 'told', 'advcl', '4', 'ask'), ('9', 'that', 'mark', '15', 'will'), ('10', 'a', 'det', '12', 'attack'), ('11', 'U.S.', 'compound', '12', 'attack'), ('12', 'attack', 'nsubj', '15', 'will'), ('13', 'on', 'case', '14', 'Iran'), ('14', 'Iran', 'nmod', '12', 'attack'), ('15', 'will', 'ccomp', '8', 'told'), ('16', '(', 'punct', '22', 'put'), ('17', 'as', 'mark', '22', 'put'), ('18', 'IAEA', 'compound', '19', 'chief'), ('19', 'chief', 'compound', '20', 'ElBaradei'), ('20', 'ElBaradei', 'nsubj', '22', 'put'), ('21', 'recently', 'advmod', '22', 'put'), ('22', 'put', 'advcl', '15', 'will'), ('23', 'it', 'obj', '22', 'put'), ('24', ')', 'punct', '22', 'put'), ('25', ',', 'punct', '26', 'transform'), ('26', 'transform', 'ccomp', '8', 'told'), ('27', 'the', 'det', '29', 'East'), ('28', 'Middle', 'compound', '29', 'East'), ('29', 'East', 'obj', '26', 'transform'), ('30', 'into', 'case', '33', 'ball'), ('31', '""', 'punct', '33', 'ball'), ('32', 'a', 'det', '33', 'ball'), ('33', 'ball', 'obl', '26', 'transform'), ('34', 'of', 'case', '35', 'fire'), ('35', 'fire', 'nmod', '33', 'ball'), ('36', '.', 'punct', '4', 'ask'), ('37', '""', 'punct', '4', 'ask')]","'Perhaps': 1
# 'he': 2
# ''d': 3
# 'ask': 4
# 'the': 5
# 'same': 6
# 'if': 7
# 'told': 8
# 'that': 9
# 'a': 10
# 'U.S.': 11
# 'attack': 12
# 'on': 13
# 'Iran': 14
# 'will': 15
# '(': 16
# 'as': 17
# 'IAEA': 18
# 'chief': 19
# 'ElBaradei': 20
# 'recently': 21
# 'put': 22
# 'it': 23
# ')': 24
# ',': 25
# 'transform': 26
# 'the': 27
# 'Middle': 28
# 'East': 29
# 'into': 30
# '""': 31
# 'a': 32
# 'ball': 33
# 'of': 34
# 'fire': 35
# '.': 36
# '""': 37"
# 1270,"In Tuesday's Balanx statement, Ospel was quoted saying: ""I strongly believe the current solution is the right one.",Balanx,Ospel,"[('1', 'In', 'case', '5', 'statement'), ('2', 'Tuesday', 'nmod:poss', '5', 'statement'), ('3', ""'s"", 'case', '2', 'Tuesday'), ('4', 'Balanx', 'amod', '5', 'statement'), ('5', 'statement', 'obl', '9', 'quoted'), ('6', ',', 'punct', '9', 'quoted'), ('7', 'Ospel', 'nsubj:pass', '9', 'quoted'), ('8', 'was', 'aux:pass', '9', 'quoted'), ('9', 'quoted', 'root', '0', 'ROOT'), ('10', 'saying', 'advcl', '9', 'quoted'), ('11', ':', 'punct', '10', 'saying'), ('12', '""', 'punct', '10', 'saying'), ('13', 'I', 'nsubj', '15', 'believe'), ('14', 'strongly', 'advmod', '15', 'believe'), ('15', 'believe', 'ccomp', '10', 'saying'), ('16', 'the', 'det', '18', 'solution'), ('17', 'current', 'amod', '18', 'solution'), ('18', 'solution', 'nsubj', '22', 'one'), ('19', 'is', 'cop', '22', 'one'), ('20', 'the', 'det', '22', 'one'), ('21', 'right', 'amod', '22', 'one'), ('22', 'one', 'ccomp', '15', 'believe'), ('23', '.', 'punct', '9', 'quoted')]","'In': 1
# 'Tuesday': 2
# ''s': 3
# 'Balanx': 4
# 'statement': 5
# ',': 6
# 'Ospel': 7
# 'was': 8
# 'quoted': 9
# 'saying': 10
# ':': 11
# '""': 12
# 'I': 13
# 'strongly': 14
# 'believe': 15
# 'the': 16
# 'current': 17
# 'solution': 18
# 'is': 19
# 'the': 20
# 'right': 21
# 'one': 22
# '.': 23"
# 1271,"As in years past, official Washington fretted over the night for weeks, consumed by details such as who is invited to which after - party (Bloomberg News held its oh-so-exclusive soiree at the Costa Rican Embassy, while writer Christopher Hitchens and former White House press secretary Dee Dee Myers co-hosted Vanity Fair's very VIP event), which stars are attending, and whether Stephen Colbert would be headlining again.",White House,Dee Myers,"[('1', 'As', 'case', '3', 'years'), ('2', 'in', 'fixed', '1', 'As'), ('3', 'years', 'obl', '8', 'fretted'), ('4', 'past', 'advmod', '8', 'fretted'), ('5', ',', 'punct', '8', 'fretted'), ('6', 'official', 'amod', '7', 'Washington'), ('7', 'Washington', 'nsubj', '8', 'fretted'), ('8', 'fretted', 'root', '0', 'ROOT'), ('9', 'over', 'case', '11', 'night'), ('10', 'the', 'det', '11', 'night'), ('11', 'night', 'obl', '8', 'fretted'), ('12', 'for', 'case', '13', 'weeks'), ('13', 'weeks', 'obl', '8', 'fretted'), ('14', ',', 'punct', '8', 'fretted'), ('15', 'consumed', 'advcl', '8', 'fretted'), ('16', 'by', 'case', '17', 'details'), ('17', 'details', 'obl', '15', 'consumed'), ('18', 'such', 'mark', '22', 'invited'), ('19', 'as', 'fixed', '18', 'such'), ('20', 'who', 'nsubj:pass', '22', 'invited'), ('21', 'is', 'aux:pass', '22', 'invited'), ('22', 'invited', 'acl', '17', 'details'), ('23', 'to', 'case', '27', 'party'), ('24', 'which', 'det', '27', 'party'), ('25', 'after', 'case', '27', 'party'), ('26', '-', 'punct', '27', 'party'), ('27', 'party', 'obl', '22', 'invited'), ('28', '(', 'punct', '31', 'held'), ('29', 'Bloomberg', 'compound', '30', 'News'), ('30', 'News', 'nsubj', '31', 'held'), ('31', 'held', 'ccomp', '22', 'invited'), ('32', 'its', 'nmod:poss', '38', 'soiree'), ('33', 'oh', 'advmod', '37', 'exclusive'), ('34', '-', 'punct', '37', 'exclusive'), ('35', 'so', 'advmod', '37', 'exclusive'), ('36', '-', 'punct', '37', 'exclusive'), ('37', 'exclusive', 'amod', '38', 'soiree'), ('38', 'soiree', 'obj', '31', 'held'), ('39', 'at', 'case', '43', 'Embassy'), ('40', 'the', 'det', '43', 'Embassy'), ('41', 'Costa', 'compound', '43', 'Embassy'), ('42', 'Rican', 'compound', '43', 'Embassy'), ('43', 'Embassy', 'nmod', '38', 'soiree'), ('44', ',', 'punct', '31', 'held'), ('45', 'while', 'mark', '58', 'co-hosted'), ('46', 'writer', 'compound', '47', 'Christopher'), ('47', 'Christopher', 'nsubj', '58', 'co-hosted'), ('48', 'Hitchens', 'flat', '47', 'Christopher'), ('49', 'and', 'cc', '54', 'secretary'), ('50', 'former', 'amod', '54', 'secretary'), ('51', 'White', 'compound', '52', 'House'), ('52', 'House', 'compound', '54', 'secretary'), ('53', 'press', 'compound', '54', 'secretary'), ('54', 'secretary', 'compound', '55', 'Dee'), ('55', 'Dee', 'conj', '47', 'Christopher'), ('56', 'Dee', 'flat', '55', 'Dee'), ('57', 'Myers', 'flat', '55', 'Dee'), ('58', 'co-hosted', 'advcl', '31', 'held'), ('59', 'Vanity', 'compound', '60', 'Fair'), ('60', 'Fair', 'nmod:poss', '64', 'event'), ('61', ""'s"", 'case', '60', 'Fair'), ('62', 'very', 'advmod', '63', 'VIP'), ('63', 'VIP', 'amod', '64', 'event'), ('64', 'event', 'obj', '58', 'co-hosted'), ('65', ')', 'punct', '58', 'co-hosted'), ('66', ',', 'punct', '58', 'co-hosted'), ('67', 'which', 'obj', '70', 'attending'), ('68', 'stars', 'nsubj', '70', 'attending'), ('69', 'are', 'aux', '70', 'attending'), ('70', 'attending', 'acl:relcl', '64', 'event'), ('71', ',', 'punct', '78', 'headlining'), ('72', 'and', 'cc', '78', 'headlining'), ('73', 'whether', 'mark', '78', 'headlining'), ('74', 'Stephen', 'nsubj', '78', 'headlining'), ('75', 'Colbert', 'flat', '74', 'Stephen'), ('76', 'would', 'aux', '78', 'headlining'), ('77', 'be', 'aux', '78', 'headlining'), ('78', 'headlining', 'conj', '70', 'attending'), ('79', 'again', 'advmod', '78', 'headlining'), ('80', '.', 'punct', '8', 'fretted')]","'As': 1
# 'in': 2
# 'years': 3
# 'past': 4
# ',': 5
# 'official': 6
# 'Washington': 7
# 'fretted': 8
# 'over': 9
# 'the': 10
# 'night': 11
# 'for': 12
# 'weeks': 13
# ',': 14
# 'consumed': 15
# 'by': 16
# 'details': 17
# 'such': 18
# 'as': 19
# 'who': 20
# 'is': 21
# 'invited': 22
# 'to': 23
# 'which': 24
# 'after': 25
# '-': 26
# 'party': 27
# '(': 28
# 'Bloomberg': 29
# 'News': 30
# 'held': 31
# 'its': 32
# 'oh': 33
# '-': 34
# 'so': 35
# '-': 36
# 'exclusive': 37
# 'soiree': 38
# 'at': 39
# 'the': 40
# 'Costa': 41
# 'Rican': 42
# 'Embassy': 43
# ',': 44
# 'while': 45
# 'writer': 46
# 'Christopher': 47
# 'Hitchens': 48
# 'and': 49
# 'former': 50
# 'White': 51
# 'House': 52
# 'press': 53
# 'secretary': 54
# 'Dee': 55
# 'Dee': 56
# 'Myers': 57
# 'co-hosted': 58
# 'Vanity': 59
# 'Fair': 60
# ''s': 61
# 'very': 62
# 'VIP': 63
# 'event': 64
# ')': 65
# ',': 66
# 'which': 67
# 'stars': 68
# 'are': 69
# 'attending': 70
# ',': 71
# 'and': 72
# 'whether': 73
# 'Stephen': 74
# 'Colbert': 75
# 'would': 76
# 'be': 77
# 'headlining': 78
# 'again': 79
# '.': 80"
